# %% [markdown]
# # Scraping apple products prices and review info from www.abt.com

# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import csv
import pandas as pd
import numpy as np
import re 
import mariadb
import sys

# %% [markdown]
# ## Exploration and research
#
# This part before the next heading shows the main part of process of researching or finding a solution, is not part of the processing itself and can be skipped.

# %%
# testing with one of urls: 
url = 'https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html'
r = requests.get(url)
doc = BeautifulSoup(r.text, "html.parser")

# %%
doc.select_one('.productPageLink').attrs['href']
# Out:
# 'https://www.abt.com/Apple-128GB-Deep-Purple-iPhone-14-Pro-Cellular-Phone-MQ0E3LLA6514D/p/183648.html'

# %% [markdown]
# Scraping product page:

# %%
def scrape_prods(url): 
    r = requests.get(url)
    doc = BeautifulSoup(r.text, "html.parser")
    products = doc.select(".category_item_container")
    i = 1
    for product in products: 
        title = product.select_one('.cl_title').text.strip()
        price = product.select_one('.pricing-item-price').text.strip()
        print(i)
        print(title)
        print(price)
        if product.select_one('.abt-reviews-rating'):
            rating = product.select_one('.abt-reviews-rating .sr-only').text.strip()
            review = product.select_one('.abt-reviews-num-reviews').text.strip()
            print(rating)
            print(review)
        i +=1
    
scrape_prods(url)
# Out:
# 1
# Apple 128GB Deep Purple iPhone 14 Pro Cellular Phone - MQ0E3LL/A & 6514D
# Your Price: $999.99
# 2
# Apple 128GB Space Black iPhone 14 Pro Max Cellular Phone - MQ8N3LL/A & 6527D
# Your Price: $1,099.99
# 3
# Apple 128GB Silver iPhone 14 Pro Max Cellular Phone - MQ8P3LL/A & 6528D
# Your Price: $1,099.99
# 4
# Apple 64GB (PRODUCT)RED iPhone SE (3rd Generation) Cellular Phone - 6372D
# Your Price: $429.99
# 5
# Apple 256GB Starlight iPhone 14 Cellular Phone - MPW23LL/A & 6487D
# Your Price: $899.99
# 6
# Apple 128GB Blue iPhone 14 Plus Cellular Phone - MQ3W3LL/A & 6500D
# Your Price: $899.99
# 7
# Apple 256GB (PRODUCT)RED iPhone 14 Plus Cellular Phone - MQ413LL/A & 6504D
# Your Price: $999.99
# 5 out of 5 stars
# Contains 1 Reviews
# 8
# Apple 256GB Purple iPhone 14 Cellular Phone - MPW83LL/A & 6488D
# Your Price: $899.99
# 9
# Apple 256GB Space Black iPhone 14 Pro Cellular Phone - MQ0N3LL/A & 6515D
# Your Price: $1,099.99
# 5 out of 5 stars
# Contains 1 Reviews
# 10
# Apple 64GB Starlight iPhone SE (3rd Generation) Cellular Phone - 6371D
# Your Price: $429.99
# 11
# Apple 128GB Silver iPhone 14 Pro Cellular Phone - MQ003LL/A & 6512D
# Your Price: $999.99
# 12
# Apple 128GB Space Black iPhone 14 Pro Cellular Phone - MPXT3LL/A & 6511D
# Your Price: $999.99
# 13
# Apple 256GB Deep Purple iPhone 14 Pro Cellular Phone - MQ1D3LL/A & 6518D
# Your Price: $1,099.99
# 5 out of 5 stars
# Contains 1 Reviews
# 14
# Apple 128GB Starlight iPhone 14 Cellular Phone - MPUN3LL/A & 6482D
# Your Price: $799.99
# 15
# Apple 256GB Midnight iPhone 14 Cellular Phone - MPVV3LL/A & 6486D
# Your Price: $899.99
# 16
# Apple 256GB Gold iPhone 14 Pro Max Cellular Phone - MQ8V3LL/A & 6533D
# Your Price: $1,199.99
# 17
# Apple 128GB (PRODUCT)RED iPhone 14 Cellular Phone - MPV73LL/A & 6484D
# Your Price: $799.99
# 18
# Apple 128GB Midnight iPhone 14 Plus Cellular Phone - MQ3R3LL/A & 6496D
# Your Price: $899.99
# 19
# Apple 256GB Yellow iPhone 14 Cellular Phone - 6799D & MR3K3LL/A
# Your Price: $899.99
# 20
# Apple 256GB Starlight iPhone 14 Plus Cellular Phone - MQ3Y3LL/A & 6502D
# Your Price: $999.99
# 5 out of 5 stars
# Contains 1 Reviews

# %%
#scrpaing URL of next page of category: 

nextbutton = "Next »"  
links = doc.find_all('a', string=nextbutton)
if links:
    print(links[0].attrs['href'])
else: 
    print('It was last page')
# Out:
# https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html?category_id=1228&start_index=20

# %%
#Function for scraping next URL without arguments
def next_url():
    global url
    sl = random.randint(1,15)
    print(sl)
    time.sleep(sl)
    r = requests.get(url)
    doc = BeautifulSoup(r.text, "html.parser")
    nextbutton = "Next »"  
    links = doc.find_all('a', string=nextbutton)
    if links:
        url = links[0].attrs['href']
    else: url = 'done'
    print(url)

next_url()
url
# Out:
# 1
# https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html?category_id=1228&start_index=20
# 'https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html?category_id=1228&start_index=20'

# %%
# getting next URL with argument avoidin Global variables

def next_url2(url):
    sl = random.randint(1,10)
    print(sl)
    time.sleep(sl)
    r = requests.get(url)
    doc = BeautifulSoup(r.text, "html.parser")
    nextbutton = "Next »"  
    links = doc.find_all('a', string=nextbutton)
    if links:
        url = links[0].attrs['href']
    else: url = 'done'
    print(url)
    return(url)

next_url2(url)
# Out:
# 8
# https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html?category_id=1228&start_index=20
# 'https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html?category_id=1228&start_index=20'

# %%
# test to scrape all iphones: 

while url != 'done': 
    scrape_prods(url)
    next_url()
# Out:
# 1
# Apple 256GB Blue iPhone 14 Plus Cellular Phone - MQ423LL/A & 6505D
# Your Price: $999.99
# 5 out of 5 stars
# Contains 1 Reviews
# 2
# Apple 256GB Midnight iPhone 14 Plus Cellular Phone - MQ3X3LL/A & 6501D
# Your Price: $999.99
# 5 out of 5 stars
# Contains 1 Reviews
# 3
# Apple 64GB Midnight iPhone SE (3rd Generation) Cellular Phone - 6370D
# Your Price: $429.99
# 4
# Apple 128GB Midnight iPhone SE (3rd Generation) Cellular Phone - 6373D
# Your Price: $479.99
# 5
# Apple 128GB (PRODUCT)RED iPhone 14 Plus Cellular Phone - MQ3V3LL/A & 6499D
# Your Price: $899.99
# 6
# Apple 128GB (PRODUCT)RED iPhone SE (3rd Generation) Cellular Phone - 6375D
# Your Price: $479.99
# 7
# Apple 512GB Midnight iPhone 13 Cellular Phone - ML9Q3LL/A & 6172D
# Your Price: $1,029.99
# 17
# Apple 128GB Starlight iPhone 13 Cellular Phone - ML953LL/A & 6163D
# Your Price: $729.99
# 5 out of 5 stars
# Contains 1 Reviews
# 18
# Apple 64GB Blue iPhone 12 Cellular Phone - MGEK3LL/A & 6861C
# Your Price: $629.99
# 5 out of 5 stars
# Contains 5 Reviews
# 19
# Apple 128GB Blue iPhone 12 Cellular Phone - MGEV3LL/A & 6866C
# Your Price: $679.99
# 4 out of 5 stars
# Contains 1 Reviews
# 20
# Apple 64GB Black iPhone 12 Cellular Phone - MGEF3LL/A & 6858C
# Your Price: $629.99
# 5 out of 5 stars
# Contains 5 Reviews
# 10
# done

# %% [markdown]
# It is working solution but in this case we need to call the same URL twice wich is not the best idea. So below I combined two functions in one.

# %% [markdown]
# ## Automatization of getting URLs to scrape
# This part describe the aotomated process of gathering URLs to scrape

# %% [markdown]
# First step is to scrape URLs of categories form start page:

# %%
# Starting page with links to category pages and pages with links to other categories: 
start_url = 'https://www.abt.com/brand/apple'

r = requests.get(start_url)
doc = BeautifulSoup(r.text, "html.parser")
url_list = doc.select('.cat_list_drop')

pages_to_check = {} #dictionary (in order to avoid duplicates) with list of names of category and corresponding url.
for url in url_list:
    pages_to_check[url.text] = url.attrs['href']

pages_to_check
# Out:
# {'Computers & Tablets': 'https://www.abt.com/Apple-Computers-Tablets/bc/281-414.html',
#  'Headphones': 'https://www.abt.com/Apple-Headphones/bc/281-2089.html',
#  'Phones': 'https://www.abt.com/Apple-Phones/bc/281-9.html',
#  'Speakers': 'https://www.abt.com/Apple-Speakers/bc/281-26.html',
#  'TVs & Home Theater': 'https://www.abt.com/Apple-TVs-Home-Theater/bc/281-2261.html',
#  'Watches': 'https://www.abt.com/Apple-Watches/bc/281-995.html',
#  'Wearables': 'https://www.abt.com/Apple-Wearables/bc/281-2479.html',
#  'Audio & Video Accessories': 'https://www.abt.com/Apple-Audio-Video-Accessories/bc/281-59.html',
#  'Cell Phone Accessories': 'https://www.abt.com/Apple-Cell-Phone-Accessories/bc/281-301.html',
#  'Computer Accessories': 'https://www.abt.com/Apple-Computer-Accessories/bc/281-481.html',
#  'iPad & Tablet Accessories': 'https://www.abt.com/Apple-iPad-Tablet-Accessories/bc/281-2063.html',
#  'Watch Accessories': 'https://www.abt.com/Apple-Watch-Accessories/bc/281-1017.html'}

# %%
#final 'list' (not in pythonic meaning) with URLs of categories to scrape will be the dictionary:
pages_to_scrape = {}

for page in pages_to_check: #going throigh initial list
    url = pages_to_check[page] 
    sl = random.randint(1,5) # in order to be even more unpredictable and not to be blocked by cloudflare
    print('waiting for ', sl, 'sec')
    time.sleep(sl)
    doc = BeautifulSoup(requests.get(url).text, "html.parser")
    if doc.select_one('.category_item_container'): #if page contains block of products (items) than copy it 
        #to final list of pages to scrape 
        pages_to_scrape[url] = page # in this dictinory URLs are keys, not Category as in previous, 
        # because I want store only unique URLs, and categories could have different names probably because of SEO goals
    else: # adding pages with subcategories to list (dictionary) with pages to scrape
        subcat_links = doc.select('.category-block-link')
        for link in subcat_links:
            pages_to_scrape[link.attrs['href']] = link.text.strip()
    print('Categories to scrape: ', len(pages_to_scrape))

for url in pages_to_scrape: 
    print('Category: ', pages_to_scrape[url], 'url: ', url)
# Out:
# waiting for  1 sec
# Categories to scrape:  7
# waiting for  5 sec
# Categories to scrape:  12
# waiting for  2 sec
# Categories to scrape:  14
# waiting for  3 sec
# Categories to scrape:  18
# waiting for  5 sec
# Categories to scrape:  21
# waiting for  5 sec
# Categories to scrape:  24
# waiting for  4 sec
# Categories to scrape:  27
# waiting for  4 sec
# Categories to scrape:  30
# waiting for  2 sec
# Categories to scrape:  36
# waiting for  1 sec
# Categories to scrape:  40
# waiting for  2 sec
# Categories to scrape:  44
# waiting for  4 sec
# Categories to scrape:  45
# Category:  Apple Desktop Computers url:  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
# Category:  Apple Laptops & Notebook Computers url:  https://www.abt.com/Apple-Laptops-Notebook-Computers/bc/281-415.html
# Category:  Apple iPads url:  https://www.abt.com/Apple-iPads/bc/281-2367.html
# Category:  Apple Tablets url:  https://www.abt.com/Apple-Tablets/bc/281-2016.html
# Category:  Apple Computer Monitors url:  https://www.abt.com/Apple-Computer-Monitors/bc/281-442.html
# Category:  Apple iPad & Tablet Accessories url:  https://www.abt.com/Apple-iPad-Tablet-Accessories/bc/281-2063.html
# Category:  Apple Computer Accessories url:  https://www.abt.com/Apple-Computer-Accessories/bc/281-481.html
# Category:  Apple All Headphones url:  https://www.abt.com/Apple-All-Headphones/bc/281-2804.html
# Category:  Apple Noise Canceling Headphones url:  https://www.abt.com/Apple-Noise-Canceling-Headphones/bc/281-836.html
# Category:  Apple Wireless Headphones url:  https://www.abt.com/Apple-Wireless-Headphones/bc/281-2576.html
# Category:  Apple Earbuds & In-Ear Headphones url:  https://www.abt.com/Apple-Earbuds-In-Ear-Headphones/bc/281-2483.html
# Category:  Apple Over-Ear Headphones url:  https://www.abt.com/Apple-Over-Ear-Headphones/bc/281-2485.html
# Category:  Apple Cell Phones url:  https://www.abt.com/Apple-Cell-Phones/bc/281-1228.html
# Category:  Apple Cell Phone Accessories url:  https://www.abt.com/Apple-Cell-Phone-Accessories/bc/281-301.html
# Category:  Apple All Home Speakers url:  https://www.abt.com/Apple-All-Home-Speakers/bc/281-2827.html
# Category:  Apple Wireless Home Speakers url:  https://www.abt.com/Apple-Wireless-Home-Speakers/bc/281-2229.html
# Category:  Apple Bluetooth & Portable Speakers url:  https://www.abt.com/Apple-Bluetooth-Portable-Speakers/bc/281-358.html
# Category:  Apple Smart Speakers url:  https://www.abt.com/Apple-Smart-Speakers/bc/281-2636.html
# Category:  Apple Speakers url:  https://www.abt.com/Apple-Speakers/bc/281-26.html
# Category:  Apple Media Streaming Devices url:  https://www.abt.com/Apple-Media-Streaming-Devices/bc/281-2134.html
# Category:  Apple Audio & Video Accessories url:  https://www.abt.com/Apple-Audio-Video-Accessories/bc/281-59.html
# Category:  Apple All Watches url:  https://www.abt.com/Apple-All-Watches/bc/281-2822.html
# Category:  Apple Smartwatches url:  https://www.abt.com/Apple-Smartwatches/bc/281-2211.html
# Category:  Apple Watch Accessories url:  https://www.abt.com/Apple-Watch-Accessories/bc/281-1017.html
# Category:  Apple Headphones url:  https://www.abt.com/Apple-Headphones/bc/281-2089.html
# Category:  Apple Wearable Technology url:  https://www.abt.com/Apple-Wearable-Technology/bc/281-2351.html
# Category:  Apple Bluetooth Trackers url:  https://www.abt.com/Apple-Bluetooth-Trackers/bc/281-2811.html
# Category:  Apple Memory Cards & Accessories url:  https://www.abt.com/Apple-Memory-Cards-Accessories/bc/281-319.html
# Category:  Apple Audio & Video Cables url:  https://www.abt.com/Apple-Audio-Video-Cables/bc/281-311.html
# Category:  Apple Screen Care url:  https://www.abt.com/Apple-Screen-Care/bc/281-1157.html
# Category:  Apple iPhone Accessories url:  https://www.abt.com/Apple-iPhone-Accessories/bc/281-1126.html
# Category:  Apple Cell Phone Cables url:  https://www.abt.com/Apple-Cell-Phone-Cables/bc/281-2126.html
# Category:  Apple Cell Phone Cases url:  https://www.abt.com/Apple-Cell-Phone-Cases/bc/281-705.html
# Category:  Apple Portable Chargers/Power Banks url:  https://www.abt.com/Apple-Portable-Chargers-Power-Banks/bc/281-2218.html
# Category:  Apple Wall Chargers & Power Adapters url:  https://www.abt.com/Apple-Wall-Chargers-Power-Adapters/bc/281-703.html
# Category:  Apple Wireless Charging url:  https://www.abt.com/Apple-Wireless-Charging/bc/281-2543.html
# Category:  Apple Mouse & Keyboards url:  https://www.abt.com/Apple-Mouse-Keyboards/bc/281-643.html
# Category:  Apple Computer Hardware url:  https://www.abt.com/Apple-Computer-Hardware/bc/281-430.html
# Category:  Apple Cables & Connections url:  https://www.abt.com/Apple-Cables-Connections/bc/281-639.html
# Category:  Apple Laptop Accessories url:  https://www.abt.com/Apple-Laptop-Accessories/bc/281-641.html
# Category:  Apple iPad Cases url:  https://www.abt.com/Apple-iPad-Cases/bc/281-2064.html
# Category:  Apple iPad Cables & Docks url:  https://www.abt.com/Apple-iPad-Cables-Docks/bc/281-2067.html
# Category:  Apple Tablet Accessories url:  https://www.abt.com/Apple-Tablet-Accessories/bc/281-640.html
# Category:  Apple Tablet Stylus url:  https://www.abt.com/Apple-Tablet-Stylus/bc/281-2132.html
# Category:  Apple Watch Chargers url:  https://www.abt.com/Apple-Watch-Chargers/bc/281-2637.html

# %% [markdown]
# After this procedure there still could be pages with subcategories not products in dictionary (with SEO purposes),
# but it is ok for us since we have all necessary pages with products including main categories: phones, tablets,
# and laptops. Also important to add that I avoided to scrape same pages twice because of using dictionary.

# %% [markdown]
# ## Scraping into CSV

# %%
# function to scrape products and next url altogether, and write the result at once in CSV

def scrape_prods_to_csv(url, category): #category will be stored in CSV as well, because it will be used on next steps
    print(category)
    with open('../data/abt_rudyka_stage1.csv', 'a', newline='') as csvfile: #method is in order to just mini
        writer = csv.writer(csvfile, delimiter=';', quotechar='"', quoting=csv.QUOTE_MINIMAL) #quoting= just in case we have ';' somewhere
        sleep = random.randint(1,5) 
        print('Waiting for', sleep, 'and then scrape', url) # to be informed of the process
        time.sleep(sleep)
        r = requests.get(url)
        doc = BeautifulSoup(r.text, "html.parser")
        products = doc.select(".category_item_container")
        for product in products: 
            title = product.select_one('.cl_title').text.strip() #title of the product
            price = product.select_one('.pricing-item-price').text.strip() #all the content of tag with price 
            product_url = product.select_one('.productPageLink').attrs['href'] #url of product page
            try:
                rating = product.select_one('.abt-reviews-rating .sr-only').text.strip()
                review = product.select_one('.abt-reviews-num-reviews').text.strip()
            except AttributeError:
                rating = review = None
            writer.writerow([url, category, title, price, product_url, rating, review]) 
    nextbutton = "Next »"  #scraping URL of next page
    links = doc.find_all('a', string=nextbutton) #list of urls with only one element
    if links:
        url = links[0].attrs['href']
        print('naxt page to scrape: ', url)
        scrape_prods_to_csv(url, category) #simple recursion. Because why not

# %% [markdown]
# ## Scrpaing all the needed pages for products properties one by one:

# %%
for url, cat in pages_to_scrape.items():  
    scrape_prods_to_csv(url, cat)

print('The end')
# Out:
# Apple Desktop Computers
# Waiting for 5 and then scrape https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
# naxt page to scrape:  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html?category_id=444&start_index=20
# Apple Desktop Computers
# Waiting for 2 and then scrape https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html?category_id=444&start_index=20
# Apple Laptops & Notebook Computers
# Waiting for 5 and then scrape https://www.abt.com/Apple-Laptops-Notebook-Computers/bc/281-415.html
# naxt page to scrape:  https://www.abt.com/Apple-Laptops-Notebook-Computers/bc/281-415.html?category_id=415&start_index=20
# Apple Laptops & Notebook Computers
# Waiting for 4 and then scrape https://www.abt.com/Apple-Laptops-Notebook-Computers/bc/281-415.html?category_id=415&start_index=20
# Apple iPads
# Waiting for 3 and then scrape https://www.abt.com/Apple-iPads/bc/281-2367.html
# naxt page to scrape:  https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=20
# Apple iPads
# Waiting for 3 and then scrape https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=20
# naxt page to scrape:  https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=40
# Apple iPads
# Waiting for 4 and then scrape https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=40
# naxt page to scrape:  https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=60
# Apple iPads
# Waiting for 3 and then scrape https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=60
# naxt page to scrape:  https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=80
# Apple iPads
# Waiting for 4 and then scrape https://www.abt.com/Apple-iPads/bc/281-2367.html?category_id=2367&start_index=80
# Apple Tablets
# Waiting for 4 and then scrape https://www.abt.com/Apple-Tablets/bc/281-2016.html
# naxt page to scrape:  https://www.abt.com/Apple-Tablets/bc/281-2016.html?category_id=2016&start_index=20
# Apple Tablets
# Waiting for 3 and then scrape https://www.abt.com/Apple-Wall-Chargers-Power-Adapters/bc/281-703.html
# Apple Wireless Charging
# Waiting for 2 and then scrape https://www.abt.com/Apple-Wireless-Charging/bc/281-2543.html
# Apple Mouse & Keyboards
# Waiting for 5 and then scrape https://www.abt.com/Apple-Mouse-Keyboards/bc/281-643.html
# Apple Computer Hardware
# Waiting for 4 and then scrape https://www.abt.com/Apple-Computer-Hardware/bc/281-430.html
# Apple Cables & Connections
# Waiting for 4 and then scrape https://www.abt.com/Apple-Cables-Connections/bc/281-639.html
# naxt page to scrape:  https://www.abt.com/Apple-Cables-Connections/bc/281-639.html?category_id=639&start_index=20
# Apple Cables & Connections
# Waiting for 1 and then scrape https://www.abt.com/Apple-Cables-Connections/bc/281-639.html?category_id=639&start_index=20
# Apple Laptop Accessories
# Waiting for 4 and then scrape https://www.abt.com/Apple-Laptop-Accessories/bc/281-641.html
# Apple iPad Cases
# Waiting for 4 and then scrape https://www.abt.com/Apple-iPad-Cases/bc/281-2064.html
# Apple iPad Cables & Docks
# Waiting for 2 and then scrape https://www.abt.com/Apple-iPad-Cables-Docks/bc/281-2067.html
# Apple Tablet Accessories
# Waiting for 4 and then scrape https://www.abt.com/Apple-Tablet-Accessories/bc/281-640.html
# Apple Tablet Stylus
# Waiting for 4 and then scrape https://www.abt.com/Apple-Tablet-Stylus/bc/281-2132.html
# Apple Watch Chargers
# Waiting for 4 and then scrape https://www.abt.com/Apple-Watch-Chargers/bc/281-2637.html
# The end

# %% [markdown]
# # Stage 2: impurifying
#
# ## Checking the result

# %%
# !head -n 5 ../data/abt_rudyka_stage1.csv #checking the stored file if it is ok
# Out:
# https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html;Apple Desktop Computers;Apple Mac Mini Desktop Apple M2 Chip 8GB Unified RAM 256GB SSD (Early 2023) - MMFJ3LL/A;Sale $557.00;https://www.abt.com/Apple-Mac-Mini-Desktop-Apple-M2-Chip-8GB-Unified-RAM-256GB-SSD-Early-2023-MMFJ3LLA/p/188787.html;5 out of 5 stars;Contains 1 Reviews
# https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html;Apple Desktop Computers;"Apple Silver 24"" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MGTF3LL/A";Your Price: $1,299.00;https://www.abt.com/Apple-Silver-24-iMac-M1-8-Core-8GB-RAM-256GB-SSD-7-Core-GPU-Retina-4.5K-Desktop-Computer-2021-MGTF3LLA/p/163250.html;5 out of 5 stars;Contains 4 Reviews
# https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html;Apple Desktop Computers;"Apple Blue 24"" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MJV93LL/A";Your Price: $1,299.00;https://www.abt.com/Apple-Blue-24-iMac-M1-8-Core-8GB-RAM-256GB-SSD-7-Core-GPU-Retina-4.5K-Desktop-Computer-2021-MJV93LLA/p/163252.html;5 out of 5 stars;Contains 4 Reviews
# https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html;Apple Desktop Computers;Apple Mac Studio Desktop Apple M1 Ultra Chip 64GB Unified RAM 1TB SSD (Early 2022) - MJMW3LL/A;Your Price: $3,999.00;https://www.abt.com/Apple-Mac-Studio-Desktop-Apple-M1-Ultra-Chip-64GB-Unified-RAM-1TB-SSD-Early-2022-MJMW3LLA/p/176177.html;;
# https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html;Apple Desktop Computers;"Apple Green 24"" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MJV83LL/A";Your Price: $1,299.00;https://www.abt.com/Apple-Green-24-iMac-M1-8-Core-8GB-RAM-256GB-SSD-7-Core-GPU-Retina-4.5K-Desktop-Computer-2021-MJV83LLA/p/163251.html;5 out of 5 stars;Contains 4 Reviews

# %%
#reading the file in pandas DataFrame object
abt = pd.read_csv('../data/abt_rudyka_stage1.csv', sep =';', names = ['scraped_url', 'category', 'title', 'price', 'product_url', 'rating', 'review'])

# %%
abt.head(10)
# Out:
#                                          scraped_url                 category  \
# 0  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 1  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 2  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 3  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 4  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 5  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 6  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 7  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 8  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 9  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
#
#                                                title                  price  \
# 0  Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $557.00
# 1  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,299.00
# 2  Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 3  Apple Mac Studio Desktop Apple M1 Ultra Chip 6...  Your Price: $3,999.00
# 4  Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...  Your Price: $1,299.00
# 5  Apple Pink 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,499.00
# 6  Apple Mac Mini Desktop Apple M2 Pro Chip 16GB ...  Your Price: $1,299.00
# 7  Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...    Your Price: $799.00
# 8  Apple Mac Mini Desktop Apple M1 Chip 8GB Unifi...           Sale $869.00
# 9  Apple Pink 24" iMac M1 8-Core 8GB RAM 512GB SS...  Your Price: $1,699.00
#
#                                          product_url            rating  \
# 0  https://www.abt.com/Apple-Mac-Mini-Desktop-App...  5 out of 5 stars
# 1  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...  5 out of 5 stars
# 2  https://www.abt.com/Apple-Blue-24-iMac-M1-8-Co...  5 out of 5 stars
# 3  https://www.abt.com/Apple-Mac-Studio-Desktop-A...               NaN
# 4  https://www.abt.com/Apple-Green-24-iMac-M1-8-C...  5 out of 5 stars
# 5  https://www.abt.com/Apple-Pink-24-iMac-M1-8-Co...  5 out of 5 stars
# 6  https://www.abt.com/Apple-Mac-Mini-Desktop-App...               NaN
# 7  https://www.abt.com/Apple-Mac-Mini-Desktop-App...               NaN
# 8  https://www.abt.com/Apple-Mac-Mini-Desktop-App...  5 out of 5 stars
# 9  https://www.abt.com/Apple-Pink-24-iMac-M1-8-Co...  5 out of 5 stars
#
#                review
# 0  Contains 1 Reviews
# 1  Contains 4 Reviews
# 2  Contains 4 Reviews
# 3                 NaN
# 4  Contains 4 Reviews
# 5  Contains 1 Reviews
# 6                 NaN
# 7                 NaN
# 8  Contains 3 Reviews
# 9  Contains 1 Reviews

# %%
#check of duplicates using should be unique url of products 
sum(abt['product_url'].duplicated())
# Out:
# 405

# %% [markdown]
# ## Additional impurification
#
# Data already has natural impurities:  duplicates, NA values, incorrect types, irrelevant data or contaminated data for some values,  strings with words in prices (e.g. 'Your Price: $799.00'), reviews and ratings ('5 out of 5 stars') where only numbers needed. But this is only 4 differnt types of impurites. Need at least one more. So I impurified by increasing some prices by removing points in float number and deleting Titles of some products in order to recreate it later using URL of tha corresponding product page.

# %% [markdown]
# ### Changing prices to get outliers/misspels

# %%
# impurifying prices by removing dots, after that we can consider following prices as outliers and/or misspellings 
len(abt)

# 800+ rows so we need 85 errors to get 10 errors for 100
for i in range(1, 86):
    row = random.randint(1,805)
    abt.loc[row,'price'] = abt.loc[row,'price'].replace('.','')

# %%
abt.head(30)
# Out:
#                                           scraped_url  \
# 0   https://www.abt.com/Apple-Desktop-Computers/bc...
# 1   https://www.abt.com/Apple-Desktop-Computers/bc...
# 2   https://www.abt.com/Apple-Desktop-Computers/bc...
# 3   https://www.abt.com/Apple-Desktop-Computers/bc...
# 4   https://www.abt.com/Apple-Desktop-Computers/bc...
# 5   https://www.abt.com/Apple-Desktop-Computers/bc...
# 6   https://www.abt.com/Apple-Desktop-Computers/bc...
# 7   https://www.abt.com/Apple-Desktop-Computers/bc...
# 8   https://www.abt.com/Apple-Desktop-Computers/bc...
# 9   https://www.abt.com/Apple-Desktop-Computers/bc...
# 10  https://www.abt.com/Apple-Desktop-Computers/bc...
# 11  https://www.abt.com/Apple-Desktop-Computers/bc...
# 12  https://www.abt.com/Apple-Desktop-Computers/bc...
# 13  https://www.abt.com/Apple-Desktop-Computers/bc...
# 14  https://www.abt.com/Apple-Desktop-Computers/bc...
# 15  https://www.abt.com/Apple-Desktop-Computers/bc...
# 16  https://www.abt.com/Apple-Desktop-Computers/bc...
# 17  https://www.abt.com/Apple-Desktop-Computers/bc...
# 18  https://www.abt.com/Apple-Desktop-Computers/bc...
# 19  https://www.abt.com/Apple-Desktop-Computers/bc...
# 20  https://www.abt.com/Apple-Desktop-Computers/bc...
# 21  https://www.abt.com/Apple-Desktop-Computers/bc...
# 22  https://www.abt.com/Apple-Desktop-Computers/bc...
# 23  https://www.abt.com/Apple-Desktop-Computers/bc...
# 24  https://www.abt.com/Apple-Desktop-Computers/bc...
# 25  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 26  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 27  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 28  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 29  https://www.abt.com/Apple-Laptops-Notebook-Com...
#
#                               category  \
# 0              Apple Desktop Computers
# 1              Apple Desktop Computers
# 2              Apple Desktop Computers
# 3              Apple Desktop Computers
# 4              Apple Desktop Computers
# 5              Apple Desktop Computers
# 6              Apple Desktop Computers
# 7              Apple Desktop Computers
# 8              Apple Desktop Computers
# 9              Apple Desktop Computers
# 10             Apple Desktop Computers
# 11             Apple Desktop Computers
# 12             Apple Desktop Computers
# 13             Apple Desktop Computers
# 14             Apple Desktop Computers
# 15             Apple Desktop Computers
# 16             Apple Desktop Computers
# 17             Apple Desktop Computers
# 18             Apple Desktop Computers
# 19             Apple Desktop Computers
# 20             Apple Desktop Computers
# 21             Apple Desktop Computers
# 22             Apple Desktop Computers
# 23             Apple Desktop Computers
# 24             Apple Desktop Computers
# 25  Apple Laptops & Notebook Computers
# 26  Apple Laptops & Notebook Computers
# 27  Apple Laptops & Notebook Computers
# 28  Apple Laptops & Notebook Computers
# 29  Apple Laptops & Notebook Computers
#
#                                                 title                  price  \
# 0   Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $557.00
# 1   Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,299.00
# 2   Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 3   Apple Mac Studio Desktop Apple M1 Ultra Chip 6...   Your Price: $3,99900
# 4   Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...  Your Price: $1,299.00
# 5   Apple Pink 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,499.00
# 6   Apple Mac Mini Desktop Apple M2 Pro Chip 16GB ...  Your Price: $1,299.00
# 7   Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...    Your Price: $799.00
# 8   Apple Mac Mini Desktop Apple M1 Chip 8GB Unifi...           Sale $869.00
# 9   Apple Pink 24" iMac M1 8-Core 8GB RAM 512GB SS...  Your Price: $1,699.00
# 10  Apple Blue 24" iMac M1 8-Core 8GB RAM 512GB SS...   Your Price: $1,69900
# 11  Apple Green 24" iMac M1 8-Core 8GB RAM 512GB S...  Your Price: $1,699.00
# 12  Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,499.00
# 13  Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...   Your Price: $1,49900
# 14  Apple Pink 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 15  Apple Silver 24" iMac M1 8-Core 16GB RAM 512GB...   Your Price: $1,89900
# 21  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...               NaN
# 22  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...               NaN
# 23  https://www.abt.com/Apple-Mac-Pro-3.5GHz-Intel...               NaN
# 24  https://www.abt.com/Apple-Mac-Pro-3.5GHz-6-Cor...               NaN
# 25  https://www.abt.com/Apple-MacBook-Air-13.6-Mid...  5 out of 5 stars
# 26  https://www.abt.com/Apple-MacBook-Pro-13.3-Spa...               NaN
# 27  https://www.abt.com/Apple-MacBook-Pro-14-Space...               NaN
# 28  https://www.abt.com/Apple-MacBook-Air-13.6-Sta...  5 out of 5 stars
# 29  https://www.abt.com/Apple-MacBook-Air-13.6-Spa...  5 out of 5 stars
#
#                 review
# 0   Contains 1 Reviews
# 1   Contains 4 Reviews
# 2   Contains 4 Reviews
# 3                  NaN
# 4   Contains 4 Reviews
# 5   Contains 1 Reviews
# 6                  NaN
# 7                  NaN
# 8   Contains 3 Reviews
# 9   Contains 1 Reviews
# 10  Contains 1 Reviews
# 11  Contains 1 Reviews
# 12  Contains 1 Reviews
# 13  Contains 1 Reviews
# 14  Contains 4 Reviews
# 15                 NaN
# 16  Contains 1 Reviews
# 17                 NaN
# 18                 NaN
# 19  Contains 1 Reviews
# 20  Contains 1 Reviews
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25  Contains 1 Reviews
# 26                 NaN
# 27                 NaN
# 28  Contains 1 Reviews
# 29  Contains 1 Reviews

# %% [markdown]
# ### Removing titles to add additional NAs

# %%
#removing some of titles (in order to recreate them then from url later, 30 would be enough

for i in range(1, 30):
    row = random.randint(1,805)
    abt.loc[row,'title'] = np.nan

# %%
len(abt[abt.title.isnull()])
# Out:
# 84

# %%
abt.to_csv('../data/abt_rudyka_stage2.csv')

# %% [markdown]
# # Stage 3: Cleaning, preparation for merging, adding calculations

# %%
abt = pd.read_csv('../data/abt_rudyka_stage2.csv', sep =',', index_col = 0)

# %% [markdown]
# Clearing prices

# %%
abt.head()
# Out:
#                                          scraped_url                 category  \
# 0  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 1  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 2  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 3  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 4  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
#
#                                                title                  price  \
# 0  Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $557.00
# 1  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,299.00
# 2  Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 3  Apple Mac Studio Desktop Apple M1 Ultra Chip 6...   Your Price: $3,99900
# 4  Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...  Your Price: $1,299.00
#
#                                          product_url            rating  \
# 0  https://www.abt.com/Apple-Mac-Mini-Desktop-App...  5 out of 5 stars
# 1  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...  5 out of 5 stars
# 2  https://www.abt.com/Apple-Blue-24-iMac-M1-8-Co...  5 out of 5 stars
# 3  https://www.abt.com/Apple-Mac-Studio-Desktop-A...               NaN
# 4  https://www.abt.com/Apple-Green-24-iMac-M1-8-C...  5 out of 5 stars
#
#                review
# 0  Contains 1 Reviews
# 1  Contains 4 Reviews
# 2  Contains 4 Reviews
# 3                 NaN
# 4  Contains 4 Reviews

# %%
outliers = ~abt.price.str.contains('\.') #filter with "dirty" prices
sum(outliers)
# Out:
# 152

# %%
abt.loc[outliers, 'price'] = abt.loc[outliers, 'price'].str[:-2] +'.'+ abt.loc[outliers, 'price'].str[-2:]
# replace(r'(\d)(\d{2})$', r'\1.\2') #we have prices .00 and .99, 
# that is why simple regex was used

# %%
abt.head()
# Out:
#                                          scraped_url                 category  \
# 0  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 1  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 2  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 3  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 4  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
#
#                                                title                  price  \
# 0  Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $557.00
# 1  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,299.00
# 2  Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 3  Apple Mac Studio Desktop Apple M1 Ultra Chip 6...  Your Price: $3,999.00
# 4  Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...  Your Price: $1,299.00
#
#                                          product_url            rating  \
# 0  https://www.abt.com/Apple-Mac-Mini-Desktop-App...  5 out of 5 stars
# 1  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...  5 out of 5 stars
# 2  https://www.abt.com/Apple-Blue-24-iMac-M1-8-Co...  5 out of 5 stars
# 3  https://www.abt.com/Apple-Mac-Studio-Desktop-A...               NaN
# 4  https://www.abt.com/Apple-Green-24-iMac-M1-8-C...  5 out of 5 stars
#
#                review
# 0  Contains 1 Reviews
# 1  Contains 4 Reviews
# 2  Contains 4 Reviews
# 3                 NaN
# 4  Contains 4 Reviews

# %%
abt[~abt.price.str.contains('\.')] #despite warning everything is fine
# Out:
# Empty DataFrame
# Columns: [scraped_url, category, title, price, product_url, rating, review]
# Index: []

# %% [markdown]
# Recreating title from url

# %%
no_title = abt.title.isnull()
name_pattern = r'.com\/(.+)\/p.+' #everything after '.com/' and before next '/'

new_titles = abt[no_title].product_url.str.extract(name_pattern).replace('-',' ', regex = True) 
# variable was createdto avoid /var/folders/3t/1cf4qhj170q46d820lvp7bzc0000gn/T/ipykernel_21966/891614863.py:6: SettingWithCopyWarning: 

abt.loc[no_title, ['title']] = new_titles[0] # .loc was used to avoid ValueError: Incompatible indexer with DataFrame

# %%
sum(abt.title.isnull())
# Out:
# 0

# %% [markdown]
# Removing Duplicates

# %%
abt.drop_duplicates('product_url', inplace = True) #url of product should be unique
len(abt)
# Out:
# 484

# %% [markdown]
# ## Further cleaning and extracting values
#
# We're going to use unique model identifier for merging data for everything, except iphones, which don't have such ids on the second Swiss website, so for phone we're going to extract model name and storage.

# %% [markdown]
# ### Exploration of function and patterns
#
# This part before the next heading shows the part of process of researching or finding a proper way for exctaction needed data out of text, is not part of the processing itself and can be skipped.

# %%
model_name_pattern = r'(([A-Z]|\d|\/){9})' #model id always has 9 digits or uppercase letters

# %%
model_name_reg = re.compile(model_name_pattern) #compliling to improve performance

# %%
# checking with simple text

text = '''
Apple Watch Series 8 GPS & Cellular 45mm Gold Stainless Steel Case With S/M Starlight Sport Band - MNVX3LL/A
Your Price: $749.00
7
Apple Watch Series 8 GPS & Cellular 41mm Silver Stainless Steel Case With M/L White Sport Band - MNV83LL/A
Your Price: $699.00
'''

model_name_reg.search(text).group()
# Out:
# 'MNVX3LL/A'

# %%
#extracting model name wih applying lambda function: 
abt['model_id'] = abt['title'].apply(lambda x: model_name_reg.search(x).group() if model_name_reg.search(x) else None)

# %%
abt.head(40) #checking if that worked
# Out:
#                                           scraped_url  \
# 0   https://www.abt.com/Apple-Desktop-Computers/bc...
# 1   https://www.abt.com/Apple-Desktop-Computers/bc...
# 2   https://www.abt.com/Apple-Desktop-Computers/bc...
# 3   https://www.abt.com/Apple-Desktop-Computers/bc...
# 4   https://www.abt.com/Apple-Desktop-Computers/bc...
# 5   https://www.abt.com/Apple-Desktop-Computers/bc...
# 6   https://www.abt.com/Apple-Desktop-Computers/bc...
# 7   https://www.abt.com/Apple-Desktop-Computers/bc...
# 8   https://www.abt.com/Apple-Desktop-Computers/bc...
# 9   https://www.abt.com/Apple-Desktop-Computers/bc...
# 10  https://www.abt.com/Apple-Desktop-Computers/bc...
# 11  https://www.abt.com/Apple-Desktop-Computers/bc...
# 12  https://www.abt.com/Apple-Desktop-Computers/bc...
# 13  https://www.abt.com/Apple-Desktop-Computers/bc...
# 14  https://www.abt.com/Apple-Desktop-Computers/bc...
# 15  https://www.abt.com/Apple-Desktop-Computers/bc...
# 16  https://www.abt.com/Apple-Desktop-Computers/bc...
# 17  https://www.abt.com/Apple-Desktop-Computers/bc...
# 18  https://www.abt.com/Apple-Desktop-Computers/bc...
# 19  https://www.abt.com/Apple-Desktop-Computers/bc...
# 20  https://www.abt.com/Apple-Desktop-Computers/bc...
# 21  https://www.abt.com/Apple-Desktop-Computers/bc...
# 22  https://www.abt.com/Apple-Desktop-Computers/bc...
# 23  https://www.abt.com/Apple-Desktop-Computers/bc...
# 24  https://www.abt.com/Apple-Desktop-Computers/bc...
# 25  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 26  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 27  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 28  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 29  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 30  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 31  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 32  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 33  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 34  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 35  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 36  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 37  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 38  https://www.abt.com/Apple-Laptops-Notebook-Com...
# 39  https://www.abt.com/Apple-Laptops-Notebook-Com...
#
#                               category  \
# 0              Apple Desktop Computers
# 1              Apple Desktop Computers
# 2              Apple Desktop Computers
# 3              Apple Desktop Computers
# 4              Apple Desktop Computers
# 5              Apple Desktop Computers
# 6              Apple Desktop Computers
# 7              Apple Desktop Computers
# 8              Apple Desktop Computers
# 9              Apple Desktop Computers
# 10             Apple Desktop Computers
# 11             Apple Desktop Computers
# 12             Apple Desktop Computers
# 13             Apple Desktop Computers
# 14             Apple Desktop Computers
# 15             Apple Desktop Computers
# 16             Apple Desktop Computers
# 17             Apple Desktop Computers
# 18             Apple Desktop Computers
# 19             Apple Desktop Computers
# 20             Apple Desktop Computers
# 21             Apple Desktop Computers
# 22             Apple Desktop Computers
# 23             Apple Desktop Computers
# 24             Apple Desktop Computers
# 25  Apple Laptops & Notebook Computers
# 26  Apple Laptops & Notebook Computers
# 27  Apple Laptops & Notebook Computers
# 28  Apple Laptops & Notebook Computers
# 29  Apple Laptops & Notebook Computers
# 30  Apple Laptops & Notebook Computers
# 31  Apple Laptops & Notebook Computers
# 32  Apple Laptops & Notebook Computers
# 33  Apple Laptops & Notebook Computers
# 34  Apple Laptops & Notebook Computers
# 35  Apple Laptops & Notebook Computers
# 36  Apple Laptops & Notebook Computers
# 37  Apple Laptops & Notebook Computers
# 38  Apple Laptops & Notebook Computers
# 39  Apple Laptops & Notebook Computers
#
#                                                 title                  price  \
# 0   Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $557.00
# 1   Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,299.00
# 2   Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 3   Apple Mac Studio Desktop Apple M1 Ultra Chip 6...  Your Price: $3,999.00
# 4   Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...  Your Price: $1,299.00
# 5   Apple Pink 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,499.00
# 6   Apple Mac Mini Desktop Apple M2 Pro Chip 16GB ...  Your Price: $1,299.00
# 7   Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $743.00
# 8   Apple Mac Mini Desktop Apple M1 Chip 8GB Unifi...           Sale $869.00
# 9   Apple Pink 24" iMac M1 8-Core 8GB RAM 512GB SS...  Your Price: $1,699.00
# 10  Apple Blue 24" iMac M1 8-Core 8GB RAM 512GB SS...  Your Price: $1,699.00
# 11  Apple Green 24" iMac M1 8-Core 8GB RAM 512GB S...  Your Price: $1,699.00
# 12  Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,499.00
# 13  Apple Green 24 iMac M1 8 Core 8GB RAM 256GB SS...  Your Price: $1,499.00
# 14  Apple Pink 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 15  Apple Silver 24" iMac M1 8-Core 16GB RAM 512GB...  Your Price: $1,899.00
# 16  Apple Purple 24" iMac M1 8-Core 8GB RAM 512GB ...  Your Price: $1,699.00
# 17  Apple Silver 24" iMac M1 Retina 4.5K Desktop C...  Your Price: $2,099.00
# 18  Apple Mac Studio Desktop Apple M1 Max Chip 32G...  Your Price: $1,999.00
# 19  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,499.00
# 20  Apple Silver 24" iMac M1 8-Core 8GB RAM 512GB ...  Your Price: $1,699.00
# 21  Apple Silver 24" iMac M1 8-Core 16GB RAM 2TB S...  Your Price: $2,499.00
# 22  Apple Silver 24" iMac M1 8-Core 16GB RAM 1TB S...  Your Price: $2,129.00
# 23  Apple Mac Pro 3.5GHz Intel Xeon W 256GB SSD, R...  Your Price: $5,999.00
# 24  Apple Mac Pro 3.5GHz 6-Core Intel Xeon E5 Desk...  Your Price: $4,399.00
# 25  Apple MacBook Air 13.6" Midnight Notebook Appl...         Sale $1,115.00
# 26  Apple MacBook Pro 13.3" Space Grey Touch Bar A...         Sale $1,249.00
# 27  Apple MacBook Pro 14" Space Grey Laptop Touch ...  Your Price: $1,859.00
# 28  Apple MacBook Air 13.6" Starlight Notebook App...  Your Price: $1,199.00
# 29  Apple MacBook Air 13.6" Space Gray Notebook Ap...  Your Price: $1,199.00
# 30  Apple MacBook Pro 14" Silver Laptop Touch ID A...  Your Price: $1,859.00
# 31  Apple MacBook Air 13.3" Silver Notebook Apple ...           Sale $929.00
# 32  Apple MacBook Pro 16" Space Grey Laptop Touch ...  Your Price: $2,324.00
# 33  Apple MacBook Pro 13.3" Silver Touch Bar And T...         Sale $1,249.00
# 34  Apple MacBook Air 13.6" Silver Notebook Apple ...  Your Price: $1,199.00
# 35  Apple MacBook Air 13.3" Gold Notebook Apple M1...           Sale $929.00
# 36  Apple MacBook Pro 16" Space Gray Laptop Touch ...  Your Price: $3,254.00
# 37  Apple MacBook Pro 13.3" Space Grey Touch Bar A...         Sale $1,394.00
# 38  Apple MacBook Pro 16" Space Gray Laptop Touch ...  Your Price: $2,649.99
# 39  Apple MacBook Air 13.6" Midnight Notebook Appl...  Your Price: $1,499.00
#
#                                           product_url            rating  \
# 0   https://www.abt.com/Apple-Mac-Mini-Desktop-App...  5 out of 5 stars
# 1   https://www.abt.com/Apple-Silver-24-iMac-M1-8-...  5 out of 5 stars
# 2   https://www.abt.com/Apple-Blue-24-iMac-M1-8-Co...  5 out of 5 stars
# 3   https://www.abt.com/Apple-Mac-Studio-Desktop-A...               NaN
# 2    Contains 4 Reviews  MJV93LL/A
# 3                   NaN  MJMW3LL/A
# 4    Contains 4 Reviews  MJV83LL/A
# 5    Contains 1 Reviews  MGPM3LL/A
# 6                   NaN  MNH73LL/A
# 7                   NaN  MMFK3LL/A
# 8    Contains 3 Reviews  MGNT3LL/A
# 9    Contains 1 Reviews  MGPN3LL/A
# 10   Contains 1 Reviews  MGPL3LL/A
# 11   Contains 1 Reviews  MGPJ3LL/A
# 12   Contains 1 Reviews  MGPK3LL/A
# 13   Contains 1 Reviews       None
# 14   Contains 4 Reviews  MJVA3LL/A
# 15                  NaN  Z12R000LU
# 16   Contains 1 Reviews  Z131000LB
# 17                  NaN  Z12Q000NV
# 18                  NaN  MJMV3LL/A
# 19   Contains 1 Reviews  MGPC3LL/A
# 20   Contains 1 Reviews  MGPD3LL/A
# 21                  NaN  Z12R000LY
# 22                  NaN  Z12R000QF
# 23                  NaN  Z0W30003V
# 24                  NaN  Z0P80001Z
# 25   Contains 1 Reviews  MLY33LL/A
# 26                  NaN  MNEH3LL/A
# 27                  NaN  MPHE3LL/A
# 28   Contains 1 Reviews  MLY13LL/A
# 29   Contains 1 Reviews  MLXW3LL/A
# 30                  NaN  MPHH3LL/A
# 31  Contains 17 Reviews  MGN93LL/A
# 32                  NaN  MNW83LL/A
# 33                  NaN  MNEP3LL/A
# 34   Contains 1 Reviews  MLXY3LL/A
# 35  Contains 17 Reviews  MGND3LL/A
# 36                  NaN  MNWA3LL/A
# 37                  NaN  MNEJ3LL/A
# 38                  NaN  MNW93LL/A
# 39                  NaN  MLY43LL/A

# %% [markdown]
# ### Extracting Model identifier (real process)

# %%
abt['model_id'] = abt['title'].str.extract(r'([A-Z\d\/]{9})') #used str.extract() method as more readable

# %% [markdown]
# ### Extracting model and storage for iPhones

# %%
# since scraped data from another website does not have unique model numbers for iPhones, 
# We decided to exclude separately for iphone: model (13, 13 pro max), and storage in separate columns

pd.set_option('display.max_colwidth', None) # to show titles fully 
iphones = abt[abt['title'].str.contains('iPhone')]

iphones_filtered = abt['title'].str.contains('iPhone')
iphones['title'].head(10)
# Out:
# 300        Apple 128GB Deep Purple iPhone 14 Pro Cellular Phone - MQ0E3LL/A & 6514D
# 301    Apple 128GB Space Black iPhone 14 Pro Max Cellular Phone - MQ8N3LL/A & 6527D
# 302         Apple 128GB Silver iPhone 14 Pro Max Cellular Phone - MQ8P3LL/A & 6528D
# 303       Apple 64GB (PRODUCT)RED iPhone SE (3rd Generation) Cellular Phone - 6372D
# 304              Apple 256GB Starlight iPhone 14 Cellular Phone - MPW23LL/A & 6487D
# 305              Apple 128GB Blue iPhone 14 Plus Cellular Phone - MQ3W3LL/A & 6500D
# 306      Apple 256GB (PRODUCT)RED iPhone 14 Plus Cellular Phone - MQ413LL/A & 6504D
# 307                 Apple 256GB Purple iPhone 14 Cellular Phone - MPW83LL/A & 6488D
# 308        Apple 256GB Space Black iPhone 14 Pro Cellular Phone - MQ0N3LL/A & 6515D
# 309          Apple 64GB Starlight iPhone SE (3rd Generation) Cellular Phone - 6371D
# Name: title, dtype: object

# %%
abt[~iphones_filtered].head(5)
# Out:
#                                                    scraped_url  \
# 0  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
# 1  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
# 2  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
# 3  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
# 4  https://www.abt.com/Apple-Desktop-Computers/bc/281-444.html
#
#                   category  \
# 0  Apple Desktop Computers
# 1  Apple Desktop Computers
# 2  Apple Desktop Computers
# 3  Apple Desktop Computers
# 4  Apple Desktop Computers
#
#                                                                                                            title  \
# 0                        Apple Mac Mini Desktop Apple M2 Chip 8GB Unified RAM 256GB SSD (Early 2023) - MMFJ3LL/A
# 1  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MGTF3LL/A
# 2    Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MJV93LL/A
# 3                 Apple Mac Studio Desktop Apple M1 Ultra Chip 64GB Unified RAM 1TB SSD (Early 2022) - MJMW3LL/A
# 4   Apple Green 24" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MJV83LL/A
#
#                    price  \
# 0           Sale $557.00
# 1  Your Price: $1,299.00
# 2  Your Price: $1,299.00
# 3  Your Price: $3,999.00
# 4  Your Price: $1,299.00
#
#                                                                                                                                 product_url  \
# 0                      https://www.abt.com/Apple-Mac-Mini-Desktop-Apple-M2-Chip-8GB-Unified-RAM-256GB-SSD-Early-2023-MMFJ3LLA/p/188787.html
# 1  https://www.abt.com/Apple-Silver-24-iMac-M1-8-Core-8GB-RAM-256GB-SSD-7-Core-GPU-Retina-4.5K-Desktop-Computer-2021-MGTF3LLA/p/163250.html
# 2    https://www.abt.com/Apple-Blue-24-iMac-M1-8-Core-8GB-RAM-256GB-SSD-7-Core-GPU-Retina-4.5K-Desktop-Computer-2021-MJV93LLA/p/163252.html
# 3               https://www.abt.com/Apple-Mac-Studio-Desktop-Apple-M1-Ultra-Chip-64GB-Unified-RAM-1TB-SSD-Early-2022-MJMW3LLA/p/176177.html
# 4   https://www.abt.com/Apple-Green-24-iMac-M1-8-Core-8GB-RAM-256GB-SSD-7-Core-GPU-Retina-4.5K-Desktop-Computer-2021-MJV83LLA/p/163251.html
#
#              rating              review   model_id
# 0  5 out of 5 stars  Contains 1 Reviews  MMFJ3LL/A
# 1  5 out of 5 stars  Contains 4 Reviews  MGTF3LL/A
# 2  5 out of 5 stars  Contains 4 Reviews  MJV93LL/A
# 3               NaN                 NaN  MJMW3LL/A
# 4  5 out of 5 stars  Contains 4 Reviews  MJV83LL/A

# %%
pd.reset_option('display.max_colwidth')

#categories with word iphone
iphones['category'].unique()
# Out:
# array(['Apple Cell Phones', 'Apple iPhone Accessories',
#        'Apple Cell Phone Cases', 'Apple Portable Chargers/Power Banks',
#        'Apple Wireless Charging'], dtype=object)

# %% [markdown]
# We can see not only iphones but also accesories, so then we need to mark somehow only iphones. Then let's choose only Cell Phones category

# %%
cellphones_filter = abt['category'] == 'Apple Cell Phones'
iphones = abt[cellphones_filter]
iphones
# Out:
#                                            scraped_url           category  \
# 300  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 301  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 302  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 303  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 304  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# ..                                                 ...                ...
# 395  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 396  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 397  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 398  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 399  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
#
#                                                  title                  price  \
# 300  Apple 128GB Deep Purple iPhone 14 Pro Cellular...    Your Price: $999.99
# 301  Apple 128GB Space Black iPhone 14 Pro Max Cell...  Your Price: $1,099.99
# 302  Apple 128GB Silver iPhone 14 Pro Max Cellular ...  Your Price: $1,099.99
# 303  Apple 64GB (PRODUCT)RED iPhone SE (3rd Generat...    Your Price: $429.99
# 304  Apple 256GB Starlight iPhone 14 Cellular Phone...    Your Price: $899.99
# ..                                                 ...                    ...
# 395  Apple 512GB Midnight iPhone 13 Cellular Phone ...  Your Price: $1,029.99
# 396  Apple 128GB Starlight iPhone 13 Cellular Phone...    Your Price: $729.99
# 397  Apple 64GB Blue iPhone 12 Cellular Phone - MGE...    Your Price: $629.99
# 398  Apple 128GB Blue iPhone 12 Cellular Phone - MG...    Your Price: $679.99
# 399  Apple 64GB Black iPhone 12 Cellular Phone - MG...    Your Price: $629.99
#
#                                            product_url            rating  \
# 300  https://www.abt.com/Apple-128GB-Deep-Purple-iP...               NaN
# 301  https://www.abt.com/Apple-128GB-Space-Black-iP...               NaN
# 302  https://www.abt.com/Apple-128GB-Silver-iPhone-...               NaN
# 303  https://www.abt.com/Apple-64GB-PRODUCT-RED-iPh...               NaN
# 304  https://www.abt.com/Apple-256GB-Starlight-iPho...               NaN
# ..                                                 ...               ...
# 395  https://www.abt.com/Apple-512GB-Midnight-iPhon...               NaN
# 396  https://www.abt.com/Apple-128GB-Starlight-iPho...  5 out of 5 stars
# 397  https://www.abt.com/Apple-64GB-Blue-iPhone-12-...  5 out of 5 stars
# 398  https://www.abt.com/Apple-128GB-Blue-iPhone-12...  4 out of 5 stars
# 399  https://www.abt.com/Apple-64GB-Black-iPhone-12...  5 out of 5 stars
#
#                  review   model_id
# 300                 NaN  MQ0E3LL/A
# 301                 NaN  MQ8N3LL/A
# 302                 NaN  MQ8P3LL/A
# 303                 NaN        NaN
# 304                 NaN  MPW23LL/A
# ..                  ...        ...
# 395                 NaN  ML9Q3LL/A
# 396  Contains 1 Reviews  ML953LLA6
# 397  Contains 5 Reviews  MGEK3LL/A
# 398  Contains 1 Reviews  MGEV3LL/A
# 399  Contains 5 Reviews  MGEF3LL/A
#
# [100 rows x 8 columns]

# %%
# Extracting iphones storage' 
abt['iphone_storage'] = abt.loc[cellphones_filter,'title'].str.extract(r'(\d+[GT]B)')

# %%
# Extracting model name
abt['iphone_model'] = abt.loc[cellphones_filter,'title'].str.extract(r'iPhone (.+) Cellular')

# %%
# Extracting color
abt['iphone_color'] = abt.loc[cellphones_filter,'title'].str.extract(r'[GT]B (.+) iPhone')

# %%
abt[cellphones_filter].head(5)
# Out:
#                                            scraped_url           category  \
# 300  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 301  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 302  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 303  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 304  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
#
#                                                  title                  price  \
# 300  Apple 128GB Deep Purple iPhone 14 Pro Cellular...    Your Price: $999.99
# 301  Apple 128GB Space Black iPhone 14 Pro Max Cell...  Your Price: $1,099.99
# 302  Apple 128GB Silver iPhone 14 Pro Max Cellular ...  Your Price: $1,099.99
# 303  Apple 64GB (PRODUCT)RED iPhone SE (3rd Generat...    Your Price: $429.99
# 304  Apple 256GB Starlight iPhone 14 Cellular Phone...    Your Price: $899.99
#
#                                            product_url rating review  \
# 300  https://www.abt.com/Apple-128GB-Deep-Purple-iP...    NaN    NaN
# 301  https://www.abt.com/Apple-128GB-Space-Black-iP...    NaN    NaN
# 302  https://www.abt.com/Apple-128GB-Silver-iPhone-...    NaN    NaN
# 303  https://www.abt.com/Apple-64GB-PRODUCT-RED-iPh...    NaN    NaN
# 304  https://www.abt.com/Apple-256GB-Starlight-iPho...    NaN    NaN
#
#       model_id iphone_storage         iphone_model  iphone_color
# 300  MQ0E3LL/A          128GB               14 Pro   Deep Purple
# 301  MQ8N3LL/A          128GB           14 Pro Max   Space Black
# 302  MQ8P3LL/A          128GB           14 Pro Max        Silver
# 303        NaN           64GB  SE (3rd Generation)  (PRODUCT)RED
# 304  MPW23LL/A          256GB                   14     Starlight

# %% [markdown]
# ## Exctracting and changing types for prices, rating and reviews number

# %%
abt['price_cleaned'] = abt['price'].str.extract(r'\$(\d*\,*\d*\.\d+.+)') #extracting digits with commas and dots in price column

# %%
#removing ',' and changung type to float
abt['price_cleaned'] = abt['price_cleaned'].str.replace(',','').astype(float)

# %%
#extracting number of reviews and average rating
abt['reviews_number'] = abt['review'].str.extract(r'(\d+)').fillna(0).astype(int) #na filled in order to avoid an error

# %%
abt['rating_float'] = abt['rating'].str.extract(r'(.{1,3})\sout').astype(float) #1-3 symbols before ' out...'

# %%
abt.head() #checking the result
# Out:
#                                          scraped_url                 category  \
# 0  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 1  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 2  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 3  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
# 4  https://www.abt.com/Apple-Desktop-Computers/bc...  Apple Desktop Computers
#
#                                                title                  price  \
# 0  Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...           Sale $557.00
# 1  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...  Your Price: $1,299.00
# 2  Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SS...  Your Price: $1,299.00
# 3  Apple Mac Studio Desktop Apple M1 Ultra Chip 6...  Your Price: $3,999.00
# 4  Apple Green 24" iMac M1 8-Core 8GB RAM 256GB S...  Your Price: $1,299.00
#
#                                          product_url            rating  \
# 0  https://www.abt.com/Apple-Mac-Mini-Desktop-App...  5 out of 5 stars
# 1  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...  5 out of 5 stars
# 2  https://www.abt.com/Apple-Blue-24-iMac-M1-8-Co...  5 out of 5 stars
# 3  https://www.abt.com/Apple-Mac-Studio-Desktop-A...               NaN
# 4  https://www.abt.com/Apple-Green-24-iMac-M1-8-C...  5 out of 5 stars
#
#                review   model_id iphone_storage iphone_model iphone_color  \
# 0  Contains 1 Reviews  MMFJ3LL/A            NaN          NaN          NaN
# 1  Contains 4 Reviews  MGTF3LL/A            NaN          NaN          NaN
# 2  Contains 4 Reviews  MJV93LL/A            NaN          NaN          NaN
# 3                 NaN  MJMW3LL/A            NaN          NaN          NaN
# 4  Contains 4 Reviews  MJV83LL/A            NaN          NaN          NaN
#
#    price_cleaned  reviews_number  rating_float
# 0          557.0               1           5.0
# 1         1299.0               4           5.0
# 2         1299.0               4           5.0
# 3         3999.0               0           NaN
# 4         1299.0               4           5.0

# %% [markdown]
# ## Calculations
#
# To show some calculations, I decided to calculate the price of GB of each device. We actually don't need it in further research but that could be interesting itself.
#
# Also I added calculation for average price of iPhone model no matter which color and added price in CHF.

# %%
#Addind Cost per GB
abt['gbs'] = abt['title'].str.extract('(\d+)[GT]B(?!.*[GT]B).*').astype(float) #extracting amount of Gb or TB
abt.loc[abt['title'].str.contains('TB'), 'gbs'] *= 1000 # "converting" TB into GB
abt['price_per_gb'] = round(abt.price_cleaned/abt['gbs'],2)

# %%
abt.sort_values('price_per_gb').head() #ipads with 2TB storage have the minimum per GB price, not a big surprise
# Out:
#                                            scraped_url       category  \
# 143  https://www.abt.com/Apple-iPads/bc/281-2367.ht...    Apple iPads
# 145  https://www.abt.com/Apple-iPads/bc/281-2367.ht...    Apple iPads
# 242  https://www.abt.com/Apple-Tablets/bc/281-2016....  Apple Tablets
# 244  https://www.abt.com/Apple-Tablets/bc/281-2016....  Apple Tablets
# 151  https://www.abt.com/Apple-iPads/bc/281-2367.ht...    Apple iPads
#
#                                                  title                  price  \
# 143  Apple iPad Pro M2 11-Inch 2TB Wi-Fi Silver (20...  Your Price: $1,899.00
# 145  Apple iPad Pro M2 11-Inch 2TB Wi-Fi Space Gray...  Your Price: $1,899.00
# 242  Apple iPad Pro M2 11-Inch 2TB Wi-Fi Silver (20...  Your Price: $1,899.00
# 244  Apple iPad Pro M2 11-Inch 2TB Wi-Fi Space Gray...  Your Price: $1,899.00
# 151  Apple iPad Pro M2 11 Inch 2TB Wi Fi Cellular S...  Your Price: $2,099.00
#
#                                            product_url rating review  \
# 143  https://www.abt.com/Apple-iPad-Pro-M2-11-Inch-...    NaN    NaN
# 145  https://www.abt.com/Apple-iPad-Pro-M2-11-Inch-...    NaN    NaN
# 242  https://www.abt.com/Apple-iPad-Pro-M2-11-Inch-...    NaN    NaN
# 244  https://www.abt.com/Apple-iPad-Pro-M2-11-Inch-...    NaN    NaN
# 151  https://www.abt.com/Apple-iPad-Pro-M2-11-Inch-...    NaN    NaN
#
#       model_id iphone_storage iphone_model iphone_color  price_cleaned  \
# 143  MNXN3LL/A            NaN          NaN          NaN         1899.0
# 145  MNXM3LL/A            NaN          NaN          NaN         1899.0
# 242  MNXN3LL/A            NaN          NaN          NaN         1899.0
# 244  MNXM3LL/A            NaN          NaN          NaN         1899.0
# 151        NaN            NaN          NaN          NaN         2099.0
#
#      reviews_number  rating_float  price_per_gb
# 143               0           NaN          0.95
# 145               0           NaN          0.95
# 242               0           NaN          0.95
# 244               0           NaN          0.95
# 151               0           NaN          1.05

# %%
abt.sort_values('price_per_gb', ascending = False).head() 
#the most expensive 1 GB we have in Mac pro and some iPads with minimum storage
# Out:
#                                            scraped_url  \
# 23   https://www.abt.com/Apple-Desktop-Computers/bc...
# 114  https://www.abt.com/Apple-iPads/bc/281-2367.ht...
# 130  https://www.abt.com/Apple-iPads/bc/281-2367.ht...
# 110  https://www.abt.com/Apple-iPads/bc/281-2367.ht...
# 113  https://www.abt.com/Apple-iPads/bc/281-2367.ht...
#
#                     category  \
# 23   Apple Desktop Computers
# 114              Apple iPads
# 130              Apple iPads
# 110              Apple iPads
# 113              Apple iPads
#
#                                                  title                  price  \
# 23   Apple Mac Pro 3.5GHz Intel Xeon W 256GB SSD, R...  Your Price: $5,999.00
# 114  Apple iPad Air 64GB Wi-Fi + Cellular Space Gra...           Sale $689.00
# 130  Apple iPad mini 8.3-Inch 64GB Wi-Fi + Cellular...    Your Price: $649.99
# 110  Apple iPad Air 64GB Wi-Fi + Cellular Purple (2...           Sale $649.99
# 113  Apple iPad Air 64GB Wi-Fi + Cellular Starlight...           Sale $649.99
#
#                                            product_url            rating  \
# 23   https://www.abt.com/Apple-Mac-Pro-3.5GHz-Intel...               NaN
# 114  https://www.abt.com/Apple-iPad-Air-64GB-Wi-Fi-...               NaN
# 130  https://www.abt.com/Apple-iPad-mini-8.3-Inch-6...  4 out of 5 stars
# 110  https://www.abt.com/Apple-iPad-Air-64GB-Wi-Fi-...               NaN
# 113  https://www.abt.com/Apple-iPad-Air-64GB-Wi-Fi-...               NaN
#
#                  review   model_id iphone_storage iphone_model iphone_color  \
# 23                  NaN  Z0W30003V            NaN          NaN          NaN
# 114                 NaN  MM6R3LL/A            NaN          NaN          NaN
# 130  Contains 1 Reviews  MK893LL/A            NaN          NaN          NaN
# 110                 NaN  MME93LL/A            NaN          NaN          NaN
# 113                 NaN  MM6V3LL/A            NaN          NaN          NaN
#
#      price_cleaned  reviews_number  rating_float    gbs  price_per_gb
# 23         5999.00               0           NaN  256.0         23.43
# 114         689.00               0           NaN   64.0         10.77
# 130         649.99               1           4.0   64.0         10.16
# 110         649.99               0           NaN   64.0         10.16
# 113         649.99               0           NaN   64.0         10.16

# %%
abt.drop(['gbs'], axis = 1, inplace = True) #dont need this column anymore
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 abt.drop(['gbs'], axis = 1, inplace = True) #dont need this column anymore
#
# File ~/venv/pds01-jpy-3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/venv/pds01-jpy-3.10/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/venv/pds01-jpy-3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/venv/pds01-jpy-3.10/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/venv/pds01-jpy-3.10/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/venv/pds01-jpy-3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['gbs'] not found in axis"

# %% [markdown]
# Extracting average prices for iphone models. We will need it in future to merge iPhones. Usually the iphones of different coulours cost the same, but not always.

# %%
abt['avg_model_price'] = abt.groupby(['iphone_model','iphone_storage'])['price_cleaned'].transform('mean')

# %%
abt['avg_model_price'] = round(abt['avg_model_price'],2)
abt[cellphones_filter]['avg_model_price'] #395 index had different prices for example
# Out:
# 300     999.99
# 301    1099.99
# 302    1099.99
# 303     429.99
# 304     899.99
#         ...
# 395    1041.66
# 396     729.99
# 397     629.99
# 398     679.99
# 399     629.99
# Name: avg_model_price, Length: 100, dtype: float64

# %%
abt[iphones_filtered].head()
# Out:
#                                            scraped_url           category  \
# 300  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 301  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 302  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 303  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
# 304  https://www.abt.com/Apple-Cell-Phones/bc/281-1...  Apple Cell Phones
#
#                                                  title                  price  \
# 300  Apple 128GB Deep Purple iPhone 14 Pro Cellular...    Your Price: $999.99
# 301  Apple 128GB Space Black iPhone 14 Pro Max Cell...  Your Price: $1,099.99
# 302  Apple 128GB Silver iPhone 14 Pro Max Cellular ...  Your Price: $1,099.99
# 303  Apple 64GB (PRODUCT)RED iPhone SE (3rd Generat...    Your Price: $429.99
# 304  Apple 256GB Starlight iPhone 14 Cellular Phone...    Your Price: $899.99
#
#                                            product_url rating review  \
# 300  https://www.abt.com/Apple-128GB-Deep-Purple-iP...    NaN    NaN
# 301  https://www.abt.com/Apple-128GB-Space-Black-iP...    NaN    NaN
# 302  https://www.abt.com/Apple-128GB-Silver-iPhone-...    NaN    NaN
# 303  https://www.abt.com/Apple-64GB-PRODUCT-RED-iPh...    NaN    NaN
# 304  https://www.abt.com/Apple-256GB-Starlight-iPho...    NaN    NaN
#
#       model_id iphone_storage         iphone_model  iphone_color  \
# 300  MQ0E3LL/A          128GB               14 Pro   Deep Purple
# 301  MQ8N3LL/A          128GB           14 Pro Max   Space Black
# 302  MQ8P3LL/A          128GB           14 Pro Max        Silver
# 303        NaN           64GB  SE (3rd Generation)  (PRODUCT)RED
# 304  MPW23LL/A          256GB                   14     Starlight
#
#      price_cleaned  reviews_number  rating_float  price_per_gb  \
# 300         999.99               0           NaN          7.81
# 301        1099.99               0           NaN          8.59
# 302        1099.99               0           NaN          8.59
# 303         429.99               0           NaN          6.72
# 304         899.99               0           NaN          3.52
#
#      avg_model_price
# 300           999.99
# 301          1099.99
# 302          1099.99
# 303           429.99
# 304           899.99

# %% [markdown]
# Adding prices in CHF

# %%
usd_chf = 0.9046 #from bloomberg.com 25.05.23
abt['price_chf'] = round(abt.price_cleaned*usd_chf,2)

# %% [markdown]
# Droping of not needed columns:

# %%
abt.drop(['scraped_url', 'price', 'rating', 'review'], axis = 1, inplace = True)

# %%
abt.head(2)
# Out:
#                   category                                              title  \
# 0  Apple Desktop Computers  Apple Mac Mini Desktop Apple M2 Chip 8GB Unifi...
# 1  Apple Desktop Computers  Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB ...
#
#                                          product_url   model_id  \
# 0  https://www.abt.com/Apple-Mac-Mini-Desktop-App...  MMFJ3LL/A
# 1  https://www.abt.com/Apple-Silver-24-iMac-M1-8-...  MGTF3LL/A
#
#   iphone_storage iphone_model iphone_color  price_cleaned  reviews_number  \
# 0            NaN          NaN          NaN          557.0               1
# 1            NaN          NaN          NaN         1299.0               4
#
#    rating_float  price_per_gb  avg_model_price  price_chf
# 0           5.0          2.18              NaN     503.86
# 1           5.0          5.07              NaN    1175.08

# %%
abt.to_csv('../data/abt_rudyka_stage3.csv') #saving the result

# %% [markdown]
# # Uploading to MariaDB

# %%
abt = pd.read_csv('../data/abt_rudyka_stage3.csv', sep =',', index_col = 0)
len(abt)
# Out:
# 484

# %%
# Connect to MariaDB
try:
    conn = mariadb.connect(
        user="cip_user",
        password="cip_pw",
        host="127.0.0.1",             
        port=3306, 
        database="CIP"

    )
except mariadb.Error as e:
    print(f"Error connecting to MariaDB Platform: {e}")
    sys.exit(1)

# Get Cursor
cur = conn.cursor()

# Drop the table if it exists
cur.execute("DROP TABLE IF EXISTS abt_stage3")


# Define the table schema
table_schema = """
CREATE TABLE IF NOT EXISTS abt_stage3 (
    id INT AUTO_INCREMENT PRIMARY KEY,
    category VARCHAR(255),
    title VARCHAR(255),
    product_url VARCHAR(255),
    model_id VARCHAR(255),
    iphone_storage VARCHAR(255),
    iphone_model VARCHAR(255),
    iphone_color VARCHAR(255),
    price_cleaned VARCHAR(255),
    reviews_number VARCHAR(255),
    rating_float VARCHAR(255),
    price_per_gb VARCHAR(255),
    avg_model_price VARCHAR(255),
    price_chf VARCHAR(255)
)
"""

# Create the table
cur.execute(table_schema)

# Upload DataFrame data to the table
for key, row in abt.iterrows():
    insert_query = """
    INSERT INTO abt_stage3 
    (category,title, product_url, model_id, iphone_storage, iphone_model, iphone_color, price_cleaned, reviews_number, rating_float, price_per_gb, avg_model_price, price_chf) 
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """
     # Convert NaN values to None (NULL)
    row = row.where(pd.notnull(row), None)
    
    cur.execute(insert_query, tuple(row))

# Commit the changes
conn.commit()

# %% [markdown]
# Checking

# %%
# Querying three titles
try:
    cur.execute("SELECT title FROM abt_stage3 LIMIT 5;")    
except mariadb.Error as e:
    print(f"Error: {e}")
    
for (title) in cur:
    print(f"Title: {title}")
    
#checking number of rows:
try:
    cur.execute("SELECT COUNT(title) FROM abt_stage3;") 
except mariadb.Error as e:
    print(f"Error: {e}")
    
result = cur.fetchone()  # Fetch the one result
count = result[0]  # Extract the count value from result

print(f"Total Count: {count}")
# Out:
# Title: ('Apple Mac Mini Desktop Apple M2 Chip 8GB Unified RAM 256GB SSD (Early 2023) - MMFJ3LL/A',)
# Title: ('Apple Silver 24" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MGTF3LL/A',)
# Title: ('Apple Blue 24" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MJV93LL/A',)
# Title: ('Apple Mac Studio Desktop Apple M1 Ultra Chip 64GB Unified RAM 1TB SSD (Early 2022) - MJMW3LL/A',)
# Title: ('Apple Green 24" iMac M1 8-Core 8GB RAM 256GB SSD, 7-Core GPU Retina 4.5K Desktop Computer (2021) - MJV83LL/A',)
# Total Count: 484
